# %% [markdown]
# <a href="https://colab.research.google.com/github/Tbx9559/smbw/blob/main/Python_Baby_Names.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
baby_names = pd.read_csv("/content/US_Baby_Names_right.csv")

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0       Id      Name    Year Gender State  Count
# 0       11349  11350.0      Emma  2004.0      F    AK   62.0
# 1       11350  11351.0   Madison  2004.0      F    AK   48.0
# 2       11351  11352.0    Hannah  2004.0      F    AK   46.0
# 3       11352  11353.0     Grace  2004.0      F    AK   44.0
# 4       11353  11354.0     Emily  2004.0      F    AK   41.0
# 5       11354  11355.0   Abigail  2004.0      F    AK   37.0
# 6       11355  11356.0    Olivia  2004.0      F    AK   33.0
# 7       11356  11357.0  Isabella  2004.0      F    AK   30.0
# 8       11357  11358.0    Alyssa  2004.0      F    AK   29.0
# 9       11358  11359.0    Sophia  2004.0      F    AK   28.0

# %%
del baby_names['Unnamed: 0']
del baby_names['Id']

# %%
baby_names['Gender'].value_counts()
# Out:
# F    287308
# M    224752
# Name: Gender, dtype: int64

# %%
del baby_names["Year"]
names = baby_names.groupby("Name").sum()
names
# Out:
# <ipython-input-44-89cdddc74f8a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   names = baby_names.groupby("Name").sum()
#              Count
# Name
# Aadan         18.0
# Aadarsh        5.0
# Aaden       1796.0
# Aadhav         6.0
# Aadhya       217.0
# ...            ...
# Zyquavious     6.0
# Zyra          21.0
# Zyrah          5.0
# Zyria         35.0
# Zyriah        16.0
#
# [14675 rows x 1 columns]

# %%
baby_names['Name'].nunique()
# Out:
# 14675

# %%
baby_names['Name'].value_counts().idxmax()
# Out:
# 'Riley'

# %%
baby_names['Name'].value_counts().idxmin()
# Out:
# 'Areonna'

# %%
names.sort_values("Count", ascending=1)
# Out:
#                   Year     Count
# Name
# Caeleb          2011.0       5.0
# Mattilyn        2012.0       5.0
# Matthewjames    2007.0       5.0
# Camdin          2014.0       5.0
# Mathea          2013.0       5.0
# ...                ...       ...
# Ethan         532380.0  105171.0
# Michael       546422.0  105662.0
# Emma          554479.0  109905.0
# Isabella      554479.0  111848.0
# Jacob         532380.0  122926.0
#
# [14675 rows x 2 columns]

# %%
2139
# Out:
# 2139

# %%
names[names.Count == names.Count.min()].count()
# Out:
# Count    2139
# dtype: int64

# %%
baby_names['Name'].value_counts().sort_values(ascending=True).median()
# Out:
# 7.0
